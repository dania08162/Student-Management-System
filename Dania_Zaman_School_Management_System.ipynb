# %%
#ALL PUT TGT CODE
#GPA DETERMINING CODE
def converting_nums(g):
  if g >= 90:
    return 4.0
  elif g >= 80:
    return 3.0
  elif g >= 70:
    return 2.0
  elif g >= 60:
    return 1.0
  else:
    return 0.0
def gpa_calculator(s):
  classes = []
  classes.append(s["current math grade"])
  classes.append(s["current science grade"])
  classes.append(s["current english grade"])
  if "current coding grade" in s:
    classes.append(s["current coding grade"])
  grades = 0
  for g in classes:
    grades += converting_nums(g)
  gradesp3 = grades/len(classes)
  print("This is your GPA: ", gradesp3)
#ADDING ASSIGNMENTS TEACHER
def adding_assignments(student_name):
  for s in students:
    if s["name"].lower() == student_name.lower():
      new_assignment = input("Please enter the assignment name: ")
      s["assignments"].append(new_assignment)
      print("You just added a new assignment!")
      return
#TEACHER CHANGING GRADES
def teacher_changing_grades(student_name):
  ans = int(input("Would you like to change a student's grades? Please choose a number: \n\n1. Yes \n\n2. No "))
  if ans == 1:
    for s in students:
      if s["name"].lower() == student_name.lower():
        subject_change = int(input("Enter which subject's grade you want to be changed (Please enter a number): \n\n1. Math \n\n2. Science \n\n3. English \n\n4. Coding "))
        if subject_change == 1:
          if "current math grade" in s:
            grade = int(input("Please enter the new math grade (numbers only): "))
            s["current math grade"] = grade
        elif subject_change == 2:
          grade = int(input("Please enter the new science grade (numbers only): "))
          s["current science grade"] = grade
        elif subject_change == 3:
          grade = int(input("Please enter the new english grade (numbers only): "))
          s["current english grade"] = grade
        elif subject_change == 4:
          if "current coding grade" in s:
            grade = int(input("Please enter the new coding grade (numbers only): "))
            s["current coding grade"] = grade
          else:
            print("This student is not enrolled in coding.")
        return
    print("This student is not there.")
  else:
    ans2 = int(input("Would you like to go back to the teacher main menu? Please choose a number: \n\n1. Yes \n\n2. No"))
    if ans2 == 1:
      teacher()
    elif ans2 == 2:
      print("Okay! Sounds good!")
      main()
#student+teacher classes and info
students = [
    {"name": "Aaliyah", "grade" : "9", "password" : "wowza76", "parent" : "Sania Khan", "current math grade" : 91, "current science grade" : 87, "current english grade": 67, "assignments" : []},
    {"name": "Omer", "grade" : "10", "password" : "moon6741", "parent" : "Rania Sultan", "current math grade" : 81, "current science grade" : 85, "current english grade": 98, "current coding grade": 95, "assignments" : [] },
    {"name": "Yousuff", "grade" : "9", "password" : "rosemilk451", "parent" : "Iqbal Khan", "current math grade" : 65, "current science grade" : 41, "current english grade": 82, "assignments" : []},
    {"name": "Dania", "grade" : "11", "password" : "diva67", "parent" : "Faheem Mohammed", "current math grade" : 97, "current science grade" : 83, "current english grade": 97, "current coding grade": 80, "assignments" : []},
    {"name": "Faria", "grade" : "9", "password" : "google89", "parent" : "Saira Khan", "current math grade" : 57, "current science grade" : 78, "current english grade": 89, "assignments" : []},
    {"name": "Farah", "grade" : "12", "password" : "k3g76", "parent" : "Ahmed Rashid", "current math grade" : 76, "current science grade" : 56, "current english grade": 92, "current coding grade": 93, "assignments" : []},
    {"name": "Shazia", "grade" : "10", "password" : "pinky81", "parent" : "Haroon Niazi", "current math grade" : 81, "current science grade" : 84, "current english grade": 87, "assignments" : []},
    {"name": "Ayesha", "grade" : "9", "password" : "cutie90", "parent" : "Zayn Zafraan", "current math grade" : 94, "current science grade" : 95, "current english grade": 87, "current coding grade": 80, "assignments" : []},
    {"name": "Taha", "grade" : "11", "password" : "super81", "parent" : "Sania Khan", "current math grade" : 72, "current science grade" : 78, "current english grade": 41, "assignments" : []},
    {"name": "Hiba", "grade" : "12", "password" : "bellwork90", "parent" : "Hamna Amir", "current math grade" : 81, "current science grade" : 77, "current english grade": 93, "current coding grade":89, "assignments" : []},
    {"name": "Hamza", "grade" : "11", "password" : "orange12", "parent" : "Bilal Mirza", "current math grade" : 86, "current science grade" : 81, "current english grade": 93, "assignments" : []},
    {"name": "Aina", "grade" : "10", "password" : "scribble43", "parent" : "Hammad Syed", "current math grade" : 91, "current science grade" : 72, "current english grade": 90, "current coding grade":97, "assignments" : []},
    {"name": "Armaan", "grade" : "9", "password" : "mango98", "parent" : "Fahad Mustafa", "current math grade" : 76, "current science grade" : 41, "current english grade": 67, "assignments" : []},
    {"name": "Laila", "grade" : "12", "password" : "dosa67", "parent" : "Hassan Shaikh", "current math grade" : 67, "current science grade" : 54, "current english grade": 71, "current coding grade":35, "assignments" : []},
    {"name": "Nazir", "grade" : "11", "password" : "tesla98", "parent" : "Shameer Syed", "current math grade" : 98, "current science grade" : 95, "current english grade": 94, "assignments" : []},
    {"name": "Jannah", "grade" : "9", "password" : "rosey56", "parent" : "Sufia Shagufta", "current math grade" : 75, "current science grade" : 89, "current english grade": 34, "current coding grade":98, "assignments" : []},
            ]
credits= {"math" : 5, "science" : 5, "english" : 5, "coding": 5}
teachers = [
    {"name" : "Fatima", "password" : "lassi9871", "subject" : "Math"},
    {"name" : "Hassan", "password" : "star87", "subject" : "Science"},
    {"name" : "Rehan",  "password" : "camera10","subject" : "Math"},
    {"name" : "Manal", "password" : "superking87","subject" : "Science"},
    {"name" : "Safiya", "password" : "purple21", "subject" : "Math"},
    {"name" : "Ahad", "password" : "iwantsleep90", "subject" : "English"},
    {"name" : "Wahaj", "password" : "galaxy73","subject" : "English"},
    {"name" : "Iqra", "password" : "sassy78", "subject" : "Coding"},
            ]
#ADMIN VIEWING STUDENT + TEACHER AMT
def admin_looking_at_kid():
  kid_name = input("Please enter the student's name: ")
  name_not_found = False
  for s in students:
      if s["name"].lower() == kid_name.lower():
            name_not_found = True
            print("Login successful!")
            print("Name: ", s["name"])
            print("Grade: ", s["grade"])
            print("Guardian: ", s["parent"])
            answer = int(input("Would you like to view this student's report card? Please enter a number:  \n\n1. Yes \n\n2. No "))
            if answer == 1:
              print("----------------------------------------------")
              print("This is", s["name"],"'s report card 📚")
              print("----------------------------------------------")
              print("Current Math Grade: ", s["current math grade"],"%")
              if s["current math grade"] >= 90:
                print("A, Performance: Excellent")
              elif s["current math grade"] >= 80 and s["current math grade"] < 90:
                print("B, Performance: Above Average!")
              elif s["current math grade"] >= 70 and s["current math grade"] < 80:
                print("C, Performance: Average!")
              elif s["current math grade"] >= 60 and s["current math grade"] < 70:
                print("D, Performance: At Risk!")
              else:
                print("F, Performance: Failing.")
              print("----------------------------------------------")
              print("Current Science Grade: ", s["current science grade"],"%")
              if s["current science grade"] >= 90:
                print("A, Performance: Excellent")
              elif s["current science grade"] >= 80 and s["current science grade"] < 90:
                print("B, Performance: Above Average!")
              elif s["current science grade"] >= 70 and s["current science grade"] < 80:
                print("C, Performance: Average!")
              elif s["current science grade"] >= 60 and s["current science grade"] < 70:
                print("D, Performance: At Risk!")
              else:
                print("F, Performance: Failing.")
              print("----------------------------------------------")
              print("Current English Grade: ", s["current english grade"],"%")
              if s["current english grade"] >= 90:
                print("A, Performance: Excellent")
              elif s["current english grade"] >= 80 and s["current english grade"] < 90:
                print("B, Performance: Above Average!")
              elif s["current english grade"] >= 70 and s["current english grade"] < 80:
                print("C, Performance: Average!")
              elif s["current english grade"] >= 60 and s["current english grade"] < 70:
                print("D, Performance: At Risk!")
              else:
                print("F, Performance: Failing.")
              print("----------------------------------------------")
              if "current coding grade" in s:
                print("Current Coding Grade: ", s["current coding grade"],"%")
                if s["current coding grade"] >= 90:
                  print("A, Performance: Excellent")
                elif s["current coding grade"] >= 80 and s["current coding grade"] < 90:
                  print("B, Performance: Above Average!")
                elif s["current coding grade"] >= 70 and s["current coding grade"] < 80:
                  print("C, Performance: Average!")
                elif s["current coding grade"] >= 60 and s["current coding grade"] < 70:
                  print("D, Performance: At Risk!")
                else:
                  print("F, Performance: Failing.")
                print("----------------------------------------------")
              break
            question = input("Would you like to view another student? \n\n1. Yes \n\n2. No")
            if question == 1:
              admin_looking_at_kid()
            else:
              print("Okay, sounds good!")
              redo2 = int(input("Would you like to do something else? Please enter a number: \n\n1. Yes \n\n2. No"))
            if redo2 == 1:
              continue
  if not name_not_found:
    print("Student not found!")
def admin():
  admin_password = "iamtheadmin6767"
  suggested_pass = input("Hello! Please enter the admin's password: ")
  while suggested_pass != admin_password:
    print("Incorrect password; try again. ")
    suggested_pass = input("Please try again: ")
  while True:
    if suggested_pass == admin_password:
      choosing = int(input("Welcome, what would you like to do? Please choose a number. \n\n1. Add more students \n\n2. Add more teachers \n\n3. Check how many students and teachers there are \n\n4. Check on a student \n\n5. Remove a Student \n\n6. Remove a Teacher \n\n7. Back to main menu"))
      if choosing == 1:
        new_student_info = {
            "name" : input("Please enter the student's name: "),
            "grade" : int(input("Please enter the student's grade: ")),
            "password" : input("Please create a password for this student: "),
            "parent" : input("Please enter the full name of the student's parent: "),
            "current math grade": 0,
            "current english grade": 0,
            "current science grade": 0,
            "assignments" : []
        }
        students.append(new_student_info)
        print("STUDENT ADDED 🎉")
      elif choosing == 2:
        new_teacher_info = {
            "name" : input("Please enter the teachers's name: "),
            "password" : input("Please create a password for this teacher: "),
            "subject" : input("Please enter the subject that this teacher teaches: "),
        }
        teachers.append(new_teacher_info)
        print("TEACHER ADDED 🎉")
      elif choosing == 3:
        print("The amount of students here are: ", len(students))
        print("----------------------------------------------")
        for s in students:
          print(s["name"])
        print("----------------------------------------------")
        print("The amount of teachers here are: ", len(teachers))
        print("----------------------------------------------")
        for t in teachers:
          print(t["name"], t["subject"])
        print("----------------------------------------------")
      elif choosing == 4:
       admin_looking_at_kid()
      elif choosing == 5:
        person_removed = False
        taking_out_name = input("Please enter the student's name that you would like to remove.")
        for s in students:
          if s["name"].lower() == taking_out_name.lower():
            students.remove(s)
            print("Done! This student is removed.")
            person_removed = True
            break
        if not person_removed:
          print("This student is not in the system.")
      elif choosing ==6:
        taking_out_namep2 = input("Please enter the teachers's name that you would like to remove.")
        person_removedp2 = False
        for t in teachers:
          if t["name"].lower() == taking_out_namep2.lower():
            teachers.remove(t)
            print("Done! This teacher is removed.")
            person_removedp2 = True
            break
        if not person_removedp2:
            print("This teacher is not in the system.")
      elif choosing == 7:
        main()
        return
      else:
        print("Invalid choice.")
      again = int(input("Would you like to go back to the admin menu? Please enter a number. \n\n1. Yes \n\n2. No"))
      if again == 1:
        continue
      elif again == 2:
        main()
        return
#PARENTS VIEWING REPORT CARD
def parents():
  while True:
    parent_name = input("Please enter your name: ")
    name = input("Please enter your child's name: ")
    for s in students:
      if s["parent"].lower() == parent_name.lower() and s["name"].lower() == name.lower():
        while True:
          password = input("Please enter the password: ")
          if password == s["password"]:
            break
          else:
            print("The password is not correct. Please try again.")
        print("Login successful!")
        print("Name: ", s["name"])
        print("Grade: ", s["grade"])
        print("Guardian: ", s["parent"])
        answer = int(input("Would you like to view your child's report card? Please enter a number:  \n\n1. Yes \n\n2. No "))
        if answer == 1:
          print("----------------------------------------------")
          print("This is", s["name"],"'s report card 📚")
          print("----------------------------------------------")
          print("Current Math Grade: ", s["current math grade"],"%")
          if s["current math grade"] >= 90:
            print("A, Performance: Excellent")
          elif s["current math grade"] >= 80 and s["current math grade"] < 90:
            print("B, Performance: Above Average!")
          elif s["current math grade"] >= 70 and s["current math grade"] < 80:
            print("C, Performance: Average!")
          elif s["current math grade"] >= 60 and s["current math grade"] < 70:
            print("D, Performance: At Risk!")
          else:
            print("F, Performance: Failing.")
          print("----------------------------------------------")
          print("Current Science Grade: ", s["current science grade"],"%")
          if s["current science grade"] >= 90:
            print("A, Performance: Excellent")
          elif s["current science grade"] >= 80 and s["current science grade"] < 90:
            print("B, Performance: Above Average!")
          elif s["current science grade"] >= 70 and s["current science grade"] < 80:
            print("C, Performance: Average!")
          elif s["current science grade"] >= 60 and s["current science grade"] < 70:
            print("D, Performance: At Risk!")
          else:
            print("F, Performance: Failing.")
          print("----------------------------------------------")
          print("Current English Grade: ", s["current english grade"],"%")
          if s["current english grade"] >= 90:
            print("A, Performance: Excellent")
          elif s["current english grade"] >= 80 and s["current english grade"] < 90:
            print("B, Performance: Above Average!")
          elif s["current english grade"] >= 70 and s["current english grade"] < 80:
            print("C, Performance: Average!")
          elif s["current english grade"] >= 60 and s["current english grade"] < 70:
            print("D, Performance: At Risk!")
          else:
            print("F, Performance: Failing.")
          print("----------------------------------------------")
          if "current coding grade" in s:
            print("Current Coding Grade: ", s["current coding grade"],"%")
            if s["current coding grade"] >= 90:
              print("A, Performance: Excellent")
            elif s["current coding grade"] >= 80 and s["current coding grade"] < 90:
              print("B, Performance: Above Average!")
            elif s["current coding grade"] >= 70 and s["current coding grade"] < 80:
              print("C, Performance: Average!")
            elif s["current coding grade"] >= 60 and s["current coding grade"] < 70:
              print("D, Performance: At Risk!")
            else:
              print("F, Performance: Failing.")
            print("----------------------------------------------")
          return
        elif answer == 2:
          main()
          return
        else:
          print("Invalid choice.")
          continue
        redo3 = int(input("Would you like to do something else? Please enter a number: \n\n1. Yes \n\n2. No"))
        if redo3 == 1:
          continue
        else:
          main()
          return
    print("Information is incorrect. Try again.")
#NEW TEACHER LOGIN CODE
def teacher():
  name = input("Please enter your name: ")
  while True:
    password = input("Please enter your password: ")
    is_teacher_there = False
    for t in teachers:
      if t["name"].lower() == name.lower() and t["password"] == password:
        print("Login successful!")
        is_teacher_there = True
        break
    if is_teacher_there:
      break
    else:
      print("Invalid name or password. Please try again.")
      name = input("Please enter your name again: ")
      password = input("Please enter your password again: ")
  while True:
    student_name = input("Please enter the student's name: ")
    kid_there = False
    for s in students:
      if s["name"].lower() == student_name.lower():
        kid_there = True
        print("Login successful!")
        print("Name: ", s["name"])
        print("Grade: ", s["grade"])
        print("Guardian: ", s["parent"])
        option_time = int(input("Do you want to add an assignment or change a student's grades? Please enter a number: \n\n1. Assignments \n\n2. Grades \n\n3. Main Menu"))
        if option_time == 1:
          adding_assignments(student_name)
          redo2 = int(input("Would you like to do something else? Please enter a number: \n\n1. Yes \n\n2. No"))
          if redo2 == 1:
            teacher()
            return
          else:
            main()
            return
        elif option_time == 2:
          teacher_changing_grades(student_name)
          redo2 = int(input("Would you like to do something else? Please enter a number: \n\n1. Yes \n\n2. No"))
          if redo2 == 1:
            continue
          else:
            main()
            return
        elif option_time == 3:
          main()
          return
        else:
          print("Invalid Input")
        return
    if not kid_there:
      print("This student does not exist yet!")
#STUDENT LOGIN CODE
def student():
  while True:
    name = input("Please enter your name: ")
    is_student_there = False
    for s in students:
      if s["name"].lower() == name.lower():
        is_student_there = True
        while True:
          password = input("Please enter the password: ")
          if password == s["password"]:
            break
          else:
            print("The password is not correct. Please try again.")
        print("Login successful!")
        print("Name: ", s["name"])
        print("Grade: ", s["grade"])
        print("Guardian: ", s["parent"])
        answer = int(input("What would you like to view? Please enter a number:  \n\n1. Report Card \n\n2. Assignments \n\n3. Neither, Take me to the home menu."))
        if answer == 1:
          print("----------------------------------------------")
          print("This is", s["name"],"'s report card 📚")
          print("----------------------------------------------")
          print("Current Math Grade: ", s["current math grade"],"%")
          if s["current math grade"] >= 90:
            print("A, Performance: Excellent")
          elif s["current math grade"] >= 80 and s["current math grade"] < 90:
            print("B, Performance: Above Average!")
          elif s["current math grade"] >= 70 and s["current math grade"] < 80:
            print("C, Performance: Average!")
          elif s["current math grade"] >= 60 and s["current math grade"] < 70:
            print("D, Performance: At Risk!")
          else:
            print("F, Performance: Failing.")
          print("----------------------------------------------")
          print("Current Science Grade: ", s["current science grade"],"%")
          if s["current science grade"] >= 90:
            print("A, Performance: Excellent")
          elif s["current science grade"] >= 80 and s["current science grade"] < 90:
            print("B, Performance: Above Average!")
          elif s["current science grade"] >= 70 and s["current science grade"] < 80:
            print("C, Performance: Average!")
          elif s["current science grade"] >= 60 and s["current science grade"] < 70:
            print("D, Performance: At Risk!")
          else:
            print("F, Performance: Failing.")
          print("----------------------------------------------")
          print("Current English Grade: ", s["current english grade"],"%")
          if s["current english grade"] >= 90:
            print("A, Performance: Excellent")
          elif s["current english grade"] >= 80 and s["current english grade"] < 90:
            print("B, Performance: Above Average!")
          elif s["current english grade"] >= 70 and s["current english grade"] < 80:
            print("C, Performance: Average!")
          elif s["current english grade"] >= 60 and s["current english grade"] < 70:
            print("D, Performance: At Risk!")
          else:
            print("F, Performance: Failing.")
          print("----------------------------------------------")
          if "current coding grade" in s:
            print("Current Coding Grade: ", s["current coding grade"],"%")
            if s["current coding grade"] >= 90:
              print("A, Performance: Excellent")
            elif s["current coding grade"] >= 80 and s["current coding grade"] < 90:
              print("B, Performance: Above Average!")
            elif s["current coding grade"] >= 70 and s["current coding grade"] < 80:
              print("C, Performance: Average!")
            elif s["current coding grade"] >= 60 and s["current coding grade"] < 70:
              print("D, Performance: At Risk!")
            else:
              print("F, Performance: Failing.")
            print("----------------------------------------------")
          gpa_calculator(s)
        elif answer == 2:
          print("ASSIGNMENTS: ")
          print("----------------------------------------------")
          if len(s["assignments"]) == 0:
            print("There are no assignments for you to see.")
          else:
            for a in s["assignments"]:
              print(a)
        elif answer == 3:
          print("Okay! See you next time ☺️")
          main()
          return
        else:
          print("Invalid option.")
          continue
        redo = int(input("Would you like to do something else? Please enter a number: \n\n1. Yes \n\n2. No"))
        if redo == 1:
          continue
        else:
          main()
          return
    if not is_student_there:
      print("Information is incorrect. Try again.")
#MAIN FUNCTION
def main():
  print("Hello and welcome to Dania's School Management System! Choose one (Please enter a number): \n\n1. Student \n\n2. Teacher \n\n3. Admin \n\n4. Parent \n\n5. Exit")
  ans = int(input())
  if ans==1:
    student()
  elif ans==2:
    teacher()
  elif ans==3:
    admin()
  elif ans ==4:
    parents()
  elif ans == 5:
    print("Bye! See you later 👋")
    exit()
  else:
   print("Invalid option")
main()
# Out:
# Hello and welcome to Dania's School Management System! Choose one (Please enter a number):
#
# 1. Student
#
# 2. Teacher
#
# 3. Admin
#
# 4. Parent
#
# 5. Exit
# 3
# Hello! Please enter the admin's password: admin9871
# Incorrect password; try again.
# Please try again: iamtheadmin6767
# Welcome, what would you like to do? Please choose a number.
#
# 1. Add more students
#
# 2. Add more teachers
#
# 3. Check how many students and teachers there are
#
# 4. Check on a student
#
# 5. Remove a Student
#
# 6. Remove a Teacher
#
# 7. Back to main menu5
# Please enter the student's name that you would like to remove.dania
# Done! This student is removed.
# Would you like to go back to the admin menu? Please enter a number.
#
# 1. Yes
#
# 2. No1
# Welcome, what would you like to do? Please choose a number.
#
# 1. Add more students
#
# 2. Add more teachers
#
# 3. Check how many students and teachers there are
#
# 4. Check on a student
#
# 5. Remove a Student
#
# 6. Remove a Teacher
#
# ...
